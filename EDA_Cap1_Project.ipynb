# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as st

# %%
df = pd.read_csv('test.csv')
df
# Out:
#        Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 0               0  19556  Female     Loyal Customer   52  Business travel
# 1               1  90035  Female     Loyal Customer   36  Business travel
# 2               2  12360    Male  disloyal Customer   20  Business travel
# 3               3  77959    Male     Loyal Customer   44  Business travel
# 4               4  36875  Female     Loyal Customer   49  Business travel
# ...           ...    ...     ...                ...  ...              ...
# 25971       25971  78463    Male  disloyal Customer   34  Business travel
# 25972       25972  71167    Male     Loyal Customer   23  Business travel
# 25973       25973  37675  Female     Loyal Customer   17  Personal Travel
# 25974       25974  90086    Male     Loyal Customer   14  Business travel
# 25975       25975  34799  Female     Loyal Customer   42  Personal Travel
#
#           Class  Flight Distance  Inflight wifi service  \
# ...

# %%
#levl 0

# %%
df.head()
# Out:
#    Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 0           0  19556  Female     Loyal Customer   52  Business travel
# 1           1  90035  Female     Loyal Customer   36  Business travel
# 2           2  12360    Male  disloyal Customer   20  Business travel
# 3           3  77959    Male     Loyal Customer   44  Business travel
# 4           4  36875  Female     Loyal Customer   49  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0       Eco              160                      5
# 1  Business             2863                      1
# 2       Eco              192                      2
# 3  Business             3377                      0
# 4       Eco             1182                      2
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  1  ...                       4
# ...

# %%
df['Food and drink'].value_counts()
# Out:
# Food and drink
# 4    6204
# 5    5644
# 3    5494
# 2    5395
# 1    3214
# 0      25
# Name: count, dtype: int64

# %%
df.tail()
# Out:
#        Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 25971       25971  78463    Male  disloyal Customer   34  Business travel
# 25972       25972  71167    Male     Loyal Customer   23  Business travel
# 25973       25973  37675  Female     Loyal Customer   17  Personal Travel
# 25974       25974  90086    Male     Loyal Customer   14  Business travel
# 25975       25975  34799  Female     Loyal Customer   42  Personal Travel
#
#           Class  Flight Distance  Inflight wifi service  \
# 25971  Business              526                      3
# 25972  Business              646                      4
# 25973       Eco              828                      2
# 25974  Business             1127                      3
# 25975       Eco              264                      2
#
#        Departure/Arrival time convenient  ...  Inflight entertainment  \
# 25971                                  3  ...                       4
# ...

# %%
df.shape
# Out:
# (25976, 25)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
#        'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25976 entries, 0 to 25975
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0                         25976 non-null  int64
#  1   id                                 25976 non-null  int64
#  2   Gender                             25976 non-null  object
#  3   Customer Type                      25976 non-null  object
#  4   Age                                25976 non-null  int64
#  5   Type of Travel                     25976 non-null  object
#  6   Class                              25976 non-null  object
#  7   Flight Distance                    25976 non-null  int64
#  8   Inflight wifi service              25976 non-null  int64
#  9   Departure/Arrival time convenient  25976 non-null  int64
#  10  Ease of Online booking             25976 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                            0
# id                                    0
# Gender                                0
# Customer Type                         0
# Age                                   0
# Type of Travel                        0
# Class                                 0
# Flight Distance                       0
# Inflight wifi service                 0
# Departure/Arrival time convenient     0
# Ease of Online booking                0
# Gate location                         0
# Food and drink                        0
# Online boarding                       0
# Seat comfort                          0
# Inflight entertainment                0
# On-board service                      0
# Leg room service                      0
# Baggage handling                      0
# Checkin service                       0
# Inflight service                      0
# Cleanliness                           0
# Departure Delay in Minutes            0
# ...

# %%
df['Arrival Delay in Minutes'].mean()
# Out:
# 14.74085660217047

# %%
df['Arrival Delay in Minutes'].mode()
# Out:
# 0    0.0
# Name: Arrival Delay in Minutes, dtype: float64

# %%
#treating the missing values
mode = df['Arrival Delay in Minutes'].mode()[0]

# %%
df['Arrival Delay in Minutes']=df['Arrival Delay in Minutes'].fillna(mode)

# %%
cleanmode = df['Cleanliness'].mode()[0]

# %%
df['Cleanliness']=df['Cleanliness'].fillna(cleanmode)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                           0
# id                                   0
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0             id           Age  Flight Distance  \
# count  25976.000000   25976.000000  25976.000000     25976.000000
# mean   12987.500000   65005.657992     39.620958      1193.788459
# std     7498.769632   37611.526647     15.135685       998.683999
# min        0.000000      17.000000      7.000000        31.000000
# 25%     6493.750000   32170.500000     27.000000       414.000000
# 50%    12987.500000   65319.500000     40.000000       849.000000
# 75%    19481.250000   97584.250000     51.000000      1744.000000
# max    25975.000000  129877.000000     85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count           25976.000000                       25976.000000
# mean                2.724746                           3.046812
# std                 1.335384                           1.533371
# min                 0.000000                           0.000000
# ...

# %%
duplicate_rows_data = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_data.shape)
# Out:
# number of duplicate rows:  (0, 25)

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#        Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 0               0  19556  Female     Loyal Customer   52  Business travel
# 1               1  90035  Female     Loyal Customer   36  Business travel
# 2               2  12360    Male  disloyal Customer   20  Business travel
# 3               3  77959    Male     Loyal Customer   44  Business travel
# 4               4  36875  Female     Loyal Customer   49  Business travel
# ...           ...    ...     ...                ...  ...              ...
# 25971       25971  78463    Male  disloyal Customer   34  Business travel
# 25972       25972  71167    Male     Loyal Customer   23  Business travel
# 25973       25973  37675  Female     Loyal Customer   17  Personal Travel
# 25974       25974  90086    Male     Loyal Customer   14  Business travel
# 25975       25975  34799  Female     Loyal Customer   42  Personal Travel
#
#           Class  Flight Distance  Inflight wifi service  \
# ...

# %% [markdown]
# level 1

# %%
gender_counts = df['Gender'].value_counts()
plt.figure(figsize=(4, 4))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%',startangle=70)
plt.title('Distribution of Gender')
plt.show()

# %%
df
# Out:
#        Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 0               0  19556  Female     Loyal Customer   52  Business travel
# 1               1  90035  Female     Loyal Customer   36  Business travel
# 2               2  12360    Male  disloyal Customer   20  Business travel
# 3               3  77959    Male     Loyal Customer   44  Business travel
# 4               4  36875  Female     Loyal Customer   49  Business travel
# ...           ...    ...     ...                ...  ...              ...
# 25971       25971  78463    Male  disloyal Customer   34  Business travel
# 25972       25972  71167    Male     Loyal Customer   23  Business travel
# 25973       25973  37675  Female     Loyal Customer   17  Personal Travel
# 25974       25974  90086    Male     Loyal Customer   14  Business travel
# 25975       25975  34799  Female     Loyal Customer   42  Personal Travel
#
#           Class  Flight Distance  Inflight wifi service  \
# ...

# %%
fig, ax = plt.subplots(1,2, figsize=(15,8))
CustomerType_counts = df['Customer Type'].value_counts()
sns.countplot(x='Customer Type', data=df,ax = ax[0])
ax[0].set_title('CusDistribution')
plt.pie(CustomerType_counts, labels=CustomerType_counts.index, autopct='%1.1f%%',startangle=70)
plt.title('Distribution of customer')
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 7))
sns.histplot(x=df['Age'], ax=ax[0], color='y')
sns.boxplot(x=df['Age'], ax=ax[1], color='teal')
plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize=(15,8))
travelType_counts = df['Type of Travel'].value_counts()
ax[0].set_title('Countplot of Travel Type')
sns.countplot(x = 'Type of Travel',ax = ax[0], data=df)
plt.pie(travelType_counts, labels=travelType_counts.index, autopct='%1.1f%%',startangle=70)
plt.title('Distribution of Travel Type')
plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize=(15,8))
Class_counts = df['Class'].value_counts()
ax[0].set_title('Countplot of Class')
sns.countplot(x = 'Class',ax = ax[0], data=df)
plt.pie(Class_counts, labels=Class_counts.index, autopct='%1.1f%%',startangle=70)
plt.title('class Distribution')
plt.show()

# %%
sns.displot(df['Flight Distance'], kde=True, bins=30,color='teal')
plt.title('Flight Distance')
plt.show()
# Out:
# C:\Users\Nikita\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
fig, ax = plt.subplots(1,2, figsize=(15,8))
wifi_counts = df['Inflight wifi service'].value_counts()
ax[0].set_title('Countplot of Inflight wifi service')
sns.countplot(x = 'Inflight wifi service',ax = ax[0], data=df)
plt.pie(wifi_counts, labels=wifi_counts.index, autopct='%1.1f%%',startangle=70)
plt.title('Inflight wifi service Distribution')
plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize=(15,8))
drink_counts = df['Food and drink'].value_counts()
ax[0].set_title('Countplot of Food and drink')
sns.countplot(x = 'Food and drink',ax = ax[0], data=df)
plt.pie(drink_counts, labels=drink_counts.index, autopct='%1.1f%%',startangle=70)
plt.title('Food and drink service Distribution')
plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize=(15,8))
entertainment_counts = df['Inflight entertainment'].value_counts()
ax[0].set_title('Countplot of Inflight entertainment')
sns.countplot(x = 'Inflight entertainment',ax = ax[0], data=df)
plt.pie(entertainment_counts, labels=entertainment_counts.index, autopct='%1.1f%%',startangle=70)
plt.title('Inflight entertainment service Distribution')
plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize=(15,8))
On_board_counts = df['On-board service'].value_counts()
ax[0].set_title('Countplot of On-board service')
sns.countplot(x = 'On-board service',ax = ax[0], data=df)
plt.pie(On_board_counts, labels=On_board_counts.index, autopct='%1.1f%%',startangle=70)
plt.title('On-board service service Distribution')
plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize=(15,8))
Baggage_counts = df['Baggage handling'].value_counts()
ax[0].set_title('Countplot of Baggage handling service')
sns.countplot(x = 'Baggage handling',ax = ax[0], data=df)
plt.pie(Baggage_counts, labels=Baggage_counts.index, autopct='%1.1f%%',startangle=70)
plt.title('Baggage handling service Distribution')
plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize=(15,8))
Checkin_counts = df['Checkin service'].value_counts()
ax[0].set_title('Countplot of Checkin service service')
sns.countplot(x = 'Checkin service',ax = ax[0], data=df)
plt.pie(Checkin_counts, labels=Checkin_counts.index, autopct='%1.1f%%',startangle=70)
plt.title('Checkin service service Distribution')
plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize=(15,8))
Inflight_counts = df['Inflight service'].value_counts()
ax[0].set_title('Countplot of Inflight service')
sns.countplot(x = 'Inflight service',ax = ax[0], data=df)
plt.pie(Inflight_counts, labels=Inflight_counts.index, autopct='%1.1f%%',startangle=70)
plt.title('Inflight service Distribution')
plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize=(15,8))
Cleanliness_counts = df['Cleanliness'].value_counts()
ax[0].set_title('Countplot of Cleanliness service')
sns.countplot(x = 'Cleanliness',ax = ax[0], data=df)
plt.pie(Cleanliness_counts, labels=Cleanliness_counts.index, autopct='%1.1f%%',startangle=70)
plt.title('Cleanliness service Distribution')
plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize=(15,8))
satisfaction_counts = df['satisfaction'].value_counts()
ax[0].set_title('Countplot of satisfaction service')
sns.countplot(x = 'satisfaction',ax = ax[0], data=df)
plt.pie(satisfaction_counts, labels=satisfaction_counts.index, autopct='%1.1f%%',startangle=70)
plt.title('satisfaction service Distribution')
plt.show()

# %%
df.loc[df['Departure Delay in Minutes']>30,'Departure Delay in Minutes']=df['Departure Delay in Minutes'].median()

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 7))
sns.histplot(x=df['Departure Delay in Minutes'], ax=ax[0], color='y')
sns.boxplot(x=df['Departure Delay in Minutes'], ax=ax[1], color='teal')
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 7))
sns.histplot(x=df['Arrival Delay in Minutes'], ax=ax[0], color='y')
sns.boxplot(x=df['Arrival Delay in Minutes'], ax=ax[1], color='teal')
plt.show()

# %%
df.loc[df['Arrival Delay in Minutes']>30,'Arrival Delay in Minutes']=df['Arrival Delay in Minutes'].median()

# %%
#LEVEL 2

# %%
gender = pd.crosstab(df['satisfaction'],df['Gender'])
gender
# Out:
# Gender                   Female  Male
# satisfaction
# neutral or dissatisfied    7437  7136
# satisfied                  5735  5668

# %%
total_sum_female = gender['Female'].sum()
dissatified_female = gender['Female'][0]
percentage_dissatified_female = dissatified_female*100/total_sum_female

total_sum_male = gender['Male'].sum()
dissatified_male = gender['Male'][1]
percentage_dissatified_male = dissatified_male*100/total_sum_male

# %%
percentage_dissatified_male
# Out:
# 44.26741643236488

# %%
percentage_dissatified_female
# Out:
# 56.46067415730337

# %%
plt.bar(x=['dissatified_female','dissatified_male'], height=[percentage_dissatified_female ,percentage_dissatified_male])
plt.ylabel('percentage of disatisfation and neutral')
plt.xlabel('Genderwise disatisfation and neutral')
# Out:
# Text(0.5, 0, 'Genderwise disatisfation and neutral')

# %%
fig,ax= plt.subplots(figsize=(15,7))
sns.countplot(x='satisfaction',hue='Gender', data=df)
plt.show()

# %%
Customer = pd.crosstab(df['satisfaction'],df['Customer Type'])
Customer
# Out:
# Customer Type            Loyal Customer  disloyal Customer
# satisfaction
# neutral or dissatisfied           10982               3591
# satisfied                         10195               1208

# %%
total_sum_loyal_Customer = Customer['Loyal Customer'].sum()
dissatified_loyal_Customer = Customer['Loyal Customer'][0]
percentage_dissatified_loyal_Customer = dissatified_loyal_Customer*100/total_sum_loyal_Customer

total_sum_disloyal_Customer = Customer['disloyal Customer'].sum()
dissatified_disloyal_Customer = Customer['disloyal Customer'][0]
percentage_dissatified_disloyal_Customer = dissatified_disloyal_Customer*100/total_sum_disloyal_Customer

# %%
percentage_dissatified_disloyal_Customer
# Out:
# 74.82808918524692

# %%
percentage_dissatified_loyal_Customer
# Out:
# 51.858147990744676

# %%
plt.bar(x=['dissatified_loyal_Customer','dissatified_disloyal_Customer'], height=[percentage_dissatified_loyal_Customer ,percentage_dissatified_disloyal_Customer])
plt.ylabel('percentage of dissatified_loyal_Customer')
plt.xlabel('Genderwise dissatified_disloyal_Customer')
# Out:
# Text(0.5, 0, 'Genderwise dissatified_disloyal_Customer')

# %%
fig,ax= plt.subplots(figsize=(15,7))
sns.countplot(x='satisfaction',hue='Customer Type', data=df)
plt.show()

# %%
df['Age'].value_counts()
# Out:
# Age
# 39    723
# 25    713
# 40    635
# 41    633
# 43    626
#      ...
# 75     15
# 74     14
# 78     11
# 79     10
# 85      8
# Name: count, Length: 75, dtype: int64

# %%
satis_age= df.groupby('satisfaction')['Age'].mean()
satis_age
# Out:
# satisfaction
# neutral or dissatisfied    37.991628
# satisfied                  41.703236
# Name: Age, dtype: float64

# %%
dissatisfied= df[df['satisfaction']=='neutral or dissatisfied']
plt.hist(dissatisfied['Age'])
# Out:
# (array([1050., 1698., 2785., 2309., 1878., 1776., 1600., 1206.,  234.,
#           37.]),
#  array([ 7. , 14.8, 22.6, 30.4, 38.2, 46. , 53.8, 61.6, 69.4, 77.2, 85. ]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax= plt.subplots(1,2 , figsize=(15,7))
sns.histplot(x=df['Age'], hue= df['satisfaction'], ax= ax[0])
sns.boxplot(y=df['Age'], x= df['satisfaction'], ax= ax[1])

plt.show()

# %%
#person who are travelling for personl reason and using eco class
#i also need tp use group by
eco = pd.crosstab(df['Class'], df['Type of Travel'])
eco
# Out:
# Type of Travel  Business travel  Personal Travel
# Class
# Business                  11979              516
# Eco                        5047             6517
# Eco Plus                   1012              905

# %%
total_sum_Business_travel = eco['Business travel'].sum()
Business_travel = eco['Business travel'][0]
percentage_Business_travel = Business_travel*100/total_sum_Business_travel

Business_eco_travel = eco['Business travel'][1]
percentage_Business_eco_travel = Business_eco_travel*100/total_sum_Business_travel

Business_ecoplus_travel = eco['Business travel'][2]
percentage_Business_ecoplus_travel = Business_ecoplus_travel*100/total_sum_Business_travel


total_sum_Personal_Travel = eco['Personal Travel'].sum()
Personal_business_Travel = eco['Personal Travel'][0]
percentage_Personal_business_Travel = Personal_business_Travel*100/total_sum_Personal_Travel

Personal_eco_Travel = eco['Personal Travel'][1]
percentage_Personal_eco_Travel = Personal_eco_Travel*100/total_sum_Personal_Travel

Personal_ecoplus_Travel = eco['Personal Travel'][2]
percentage_Personal_ecoplus_Travel = Personal_ecoplus_Travel*100/total_sum_Personal_Travel

# %%
total_sum_Personal_Travel
# Out:
# 7938

# %%
total_sum_Business_travel
# Out:
# 18038

# %%
percentage_Business_travel
# Out:
# 66.40980153010311

# %%
percentage_Business_eco_travel
# Out:
# 27.979820379199467

# %%
percentage_Business_ecoplus_travel
# Out:
# 5.6103780906974166

# %%
percentage_Personal_business_Travel
# Out:
# 6.500377928949358

# %%
percentage_Personal_eco_Travel
# Out:
# 82.09876543209876

# %%
percentage_Personal_ecoplus_Travel
# Out:
# 11.400856638951877

# %%
plt.bar(x=['Personal_business_Travel','Business_eco_travel','Business_ecoplus_travel'], height=[percentage_Business_travel ,percentage_Business_eco_travel, percentage_Business_ecoplus_travel ])
plt.ylabel('percentage of_Business_travel')
plt.xlabel('Class Type')
# Out:
# Text(0.5, 0, 'Class Type')

# %%
plt.bar(x=['Business_travel','Personal_eco_Travel','Personal_ecoplus_Travel'], height=[percentage_Personal_business_Travel ,percentage_Personal_eco_Travel, percentage_Personal_ecoplus_Travel ])
plt.ylabel('percentage of_Personal_travel')
plt.xlabel('Class Type')
# Out:
# Text(0.5, 0, 'Class Type')

# %%
travel = pd.crosstab(df['satisfaction'],df['Type of Travel'])
travel
# Out:
# Type of Travel           Business travel  Personal Travel
# satisfaction
# neutral or dissatisfied             7428             7145
# satisfied                          10610              793

# %%
total_sum_Business_travel = travel['Business travel'].sum()
dissatified_Business_travel = travel['Business travel'][0]
percentage_dissatified_Business_travel = dissatified_Business_travel*100/total_sum_Business_travel

total_sum_Personal_Travel = travel['Personal Travel'].sum()
dissatified_Personal_Travel = travel['Personal Travel'][0]
percentage_dissatified_Personal_Travel = dissatified_Personal_Travel*100/total_sum_Personal_Travel

# %%
percentage_dissatified_Business_travel
# Out:
# 41.17973167756958

# %%
percentage_dissatified_Personal_Travel
# Out:
# 90.0100781053162

# %%
plt.bar(x=['dissatified_Business_travel','dissatified_Personal_Travel'], height=[percentage_dissatified_Business_travel ,percentage_dissatified_Personal_Travel])
plt.ylabel('percentage of dissatified_Business_travel')
plt.xlabel('Travel Type')
# Out:
# Text(0.5, 0, 'Travel Type')

# %%
fig,ax= plt.subplots(figsize=(15,7))
sns.countplot(x='satisfaction',hue='Type of Travel', data=df)
plt.show()

# %%
Class = pd.crosstab(df['satisfaction'],df['Class'])
Class
# Out:
# Class                    Business   Eco  Eco Plus
# satisfaction
# neutral or dissatisfied      3809  9322      1442
# satisfied                    8686  2242       475

# %%
total_sum_Business_class = Class['Business'].sum()
dissatified_Business_class = Class['Business'][0]
percentage_dissatified_Business_class = dissatified_Business_class*100/total_sum_Business_class

total_sum_Eco_class = Class['Eco'].sum()
dissatified_Eco_class = Class['Eco'][0]
percentage_dissatified_Eco_class = dissatified_Eco_class*100/total_sum_Eco_class

total_sum_Eco_Plus_class = Class['Eco Plus'].sum()
dissatified_Eco_Plus_class = Class['Eco Plus'][0]
percentage_dissatified_Eco_Plus_class = dissatified_Eco_Plus_class*100/total_sum_Eco_Plus_class

# %%
percentage_dissatified_Business_class
# Out:
# 30.484193677470987

# %%
percentage_dissatified_Eco_class
# Out:
# 80.61224489795919

# %%
percentage_dissatified_Eco_Plus_class
# Out:
# 75.22170057381325

# %%
plt.bar(x=['dissatified_Business_class','dissatified_Eco_class','dissatified_Eco_Plus_class'], height=[percentage_dissatified_Business_class ,percentage_dissatified_Eco_class,percentage_dissatified_Eco_Plus_class])
plt.ylabel('percentage of dissatified_class')
plt.xlabel('class')
# Out:
# Text(0.5, 0, 'class')

# %%
fig,ax= plt.subplots(figsize=(15,7))
sns.countplot(x='satisfaction',hue='Class', data=df)
plt.show()

# %%
diss= df[df['satisfaction']=='neutral or dissatisfied']
plt.hist(diss['Departure Delay in Minutes'])
# Out:
# (array([10849.,   782.,   601.,   477.,   433.,   381.,   304.,   247.,
#           235.,   264.]),
#  array([ 0.,  3.,  6.,  9., 12., 15., 18., 21., 24., 27., 30.]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax= plt.subplots(1,2 , figsize=(15,7))
sns.histplot(x=df['Departure Delay in Minutes'], hue= df['satisfaction'], ax= ax[0])
sns.boxplot(y=df['Departure Delay in Minutes'], x= df['satisfaction'], ax= ax[1])

plt.show()

# %%
diss= df[df['satisfaction']=='neutral or dissatisfied']
plt.hist(diss['Arrival Delay in Minutes'])
# Out:
# (array([10549.,   748.,   696.,   574.,   513.,   379.,   326.,   261.,
#           245.,   282.]),
#  array([ 0.,  3.,  6.,  9., 12., 15., 18., 21., 24., 27., 30.]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax= plt.subplots(1,2 , figsize=(15,7))
sns.histplot(x=df['Arrival Delay in Minutes'], hue= df['satisfaction'], ax= ax[0])
sns.boxplot(y=df['Arrival Delay in Minutes'], x= df['satisfaction'], ax= ax[1])

plt.show()

# %%
diss= df[df['satisfaction']=='neutral or dissatisfied']
plt.hist(diss['Departure/Arrival time convenient'])
# Out:
# (array([ 687.,    0., 1934.,    0., 2423.,    0., 2446.,    0., 3851.,
#         3232.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax= plt.subplots(1,2 , figsize=(15,7))
sns.histplot(x=df['Departure/Arrival time convenient'], hue= df['satisfaction'], ax= ax[0])
sns.boxplot(y=df['Departure/Arrival time convenient'], x= df['satisfaction'], ax= ax[1])

plt.show()

# %%
# LEVEL 3

# %%
satisfact= df[df['satisfaction']== 'neutral or dissatisfied']

# %%
sallu = df[(df['satisfaction']== 'neutral or dissatisfied') & (df['Class']=='Eco Plus')]
meann= satisfact['Food and drink'].mean()
sallu_mean= sallu['Food and drink'].mean()
print(meann)
print(sallu_mean)
# Out:
# 2.959925890345159
# 2.8439667128987516

# %%
ccc = pd.crosstab(satisfact['Class'], satisfact['Type of Travel'])
ccc
# Out:
# Type of Travel  Business travel  Personal Travel
# Class
# Business                   3342              467
# Eco                        3469             5853
# Eco Plus                    617              825

# %%
sns.countplot(x='Class', hue='Type of Travel',palette='viridis', data=satisfact)
plt.show()

# %%
cc = pd.crosstab(satisfact['Baggage handling'], satisfact['Type of Travel'])
cc
# Out:
# Type of Travel    Business travel  Personal Travel
# Baggage handling
# 1                             622              612
# 2                            1216              805
# 3                            2479             1454
# 4                            2375             2506
# 5                             736             1768

# %%
total_sum_Business_travel = cc['Business travel'].sum()
Business_one_travel = cc['Business travel'][1]
percentage_Business_one_travel = Business_one_travel*100/total_sum_Business_travel

Business_two_travel = cc['Business travel'][2]
percentage_Business_two_travel = Business_two_travel*100/total_sum_Business_travel

Business_three_travel = cc['Business travel'][3]
percentage_Business_three_travel = Business_three_travel*100/total_sum_Business_travel

Business_four_travel = cc['Business travel'][4]
percentage_Business_four_travel = Business_four_travel*100/total_sum_Business_travel

Business_five_travel = cc['Business travel'][5]
percentage_Business_five_travel = Business_five_travel*100/total_sum_Business_travel


total_sum_Personal_Travel = cc['Personal Travel'].sum()
Personal_one_travel = cc['Personal Travel'][1]
percentage_Personal_one_travel = Personal_one_travel*100/total_sum_Personal_Travel

Personal_two_travel = cc['Personal Travel'][2]
percentage_Personal_two_travel = Personal_two_travel*100/total_sum_Personal_Travel

Personal_three_travel = cc['Personal Travel'][3]
percentage_Personal_three_travel = Personal_three_travel*100/total_sum_Personal_Travel

Personal_four_travel = cc['Personal Travel'][4]
percentage_Personal_four_travel = Personal_four_travel*100/total_sum_Business_travel

Personal_five_travel = cc['Personal Travel'][5]
percentage_Personal_five_travel = Personal_five_travel*100/total_sum_Business_travel

# %%
print("percentage_Business_one_travel: " ,percentage_Business_one_travel)
print('percentage_Business_two_travel: ', percentage_Business_two_travel)
print('percentage_Business_three_travel: ', percentage_Business_three_travel)
print('percentage_Business_four_travel: ', percentage_Business_four_travel)
print('percentage_Business_five_travel: ', percentage_Business_five_travel)

print('percentage_Personal_one_travel: ' ,percentage_Personal_one_travel)
print('percentage_Personal_two_travel: ' ,percentage_Personal_two_travel)
print('percentage_Personal_thee_travel: ', percentage_Personal_three_travel)
print('percentage_Personal_four_travel: ', percentage_Personal_four_travel)
print('percentage_Personal_five_travel: ', percentage_Personal_five_travel)
# Out:
# percentage_Business_one_travel:  8.373721055465806
# percentage_Business_two_travel:  16.37049003769521
# percentage_Business_three_travel:  33.37372105546581
# percentage_Business_four_travel:  31.973613354873454
# percentage_Business_five_travel:  9.908454496499731
# percentage_Personal_one_travel:  8.565430370888734
# percentage_Personal_two_travel:  11.266620013995801
# percentage_Personal_thee_travel:  20.349895031490554
# percentage_Personal_four_travel:  33.73721055465805
# percentage_Personal_five_travel:  23.801830910070006

# %%
sns.countplot(x='Type of Travel', hue='Baggage handling',palette='viridis', data=satisfact)
plt.show()

# %%
c = pd.crosstab(satisfact['Food and drink'], satisfact['Type of Travel'])
c
# Out:
# Type of Travel  Business travel  Personal Travel
# Food and drink
# 0                             8               12
# 1                          1343             1236
# 2                          1739             1534
# 3                          1796             1491
# 4                          1405             1516
# 5                          1137             1356

# %%
d = pd.crosstab(satisfact['Class'], satisfact['Food and drink'])
d
# Out:
# Food and drink   0     1     2     3     4     5
# Class
# Business         2   636   899   915   726   631
# Eco             16  1667  2011  2055  1923  1650
# Eco Plus         2   276   363   317   272   212

# %%
sns.countplot(x='Type of Travel', hue='Food and drink',palette='viridis', data=satisfact)
plt.figure(figsize=(100, 10)) 
plt.show()

# %%
sns.countplot(x='Class', hue='Food and drink', data=satisfact, palette='viridis')
plt.show()

# %%
cls = pd.crosstab(satisfact['Class'],satisfact['Customer Type'])
cls
# Out:
# Customer Type  Loyal Customer  disloyal Customer
# Class
# Business                 2687               1122
# Eco                      7036               2286
# Eco Plus                 1259                183

# %%
sns.countplot(x='Class', hue='Customer Type',palette='viridis', data=satisfact)
plt.show()

# %%
df.head(3)
# Out:
#    Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 0           0  19556  Female     Loyal Customer   52  Business travel
# 1           1  90035  Female     Loyal Customer   36  Business travel
# 2           2  12360    Male  disloyal Customer   20  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0       Eco              160                      5
# 1  Business             2863                      1
# 2       Eco              192                      2
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  1  ...                       4
# 2                                  0  ...                       2
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 5                 5                 5                2
# ...

# %%
fact = df[(df['satisfaction'] == 'neutral or dissatisfied') & (df['Food and drink'] < 3)]

# %%
data= df[(df['satisfaction'] == 'neutral or dissatisfied') & ((df['Food and drink'] < 3) | (df['Baggage handling']<3) | (df['Inflight wifi service'] < 3) | (df['Departure/Arrival time convenient']<3) | (df['Seat comfort'] < 3) | (df['Online boarding']<3)| (df['Cleanliness']<3) | (df['Inflight service'] < 3) | (df['Checkin service']<3) | (df['Leg room service']<3) | (df['On-board service'] < 3) | (df['Inflight entertainment']<3))]
data
# Out:
#        Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 2               2   12360    Male  disloyal Customer   20  Business travel
# 11             11  115550  Female     Loyal Customer   33  Business travel
# 15             15   22470    Male     Loyal Customer   50  Personal Travel
# 16             16  124915  Female     Loyal Customer   31  Business travel
# 21             21   75855    Male     Loyal Customer   43  Personal Travel
# ...           ...     ...     ...                ...  ...              ...
# 25968       25968   86816    Male     Loyal Customer   41  Business travel
# 25970       25970   25309  Female  disloyal Customer   36  Business travel
# 25971       25971   78463    Male  disloyal Customer   34  Business travel
# 25973       25973   37675  Female     Loyal Customer   17  Personal Travel
# 25975       25975   34799  Female     Loyal Customer   42  Personal Travel
#
#           Class  Flight Distance  Inflight wifi service  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
#        'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
median_value = df.loc[df['Food and drink'] == 'neutral or dissatisfied', 'Food and drink'].mean()
median_value
# Out:
# nan

# %%
di= df['Food and drink'].mean()
di
# Out:
# 3.2153526331998767

# %%
why = pd.crosstab(data['Class'], data['Type of Travel'])
why
# Out:
# Type of Travel  Business travel  Personal Travel
# Class
# Business                   3111              423
# Eco                        3367             5322
# Eco Plus                    605              756

# %%
ccc
# Out:
# Type of Travel  Business travel  Personal Travel
# Class
# Business                   3342              467
# Eco                        3469             5853
# Eco Plus                    617              825

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
x = np.random.rand(50)
y = np.random.rand(50)
colors = np.random.rand(50)  # Random colors for each dot
sizes = 1000 * np.random.rand(50)  # Random sizes for each dot

sns.scatterplot(x=x, hue=y, palette='viridis') # 'viridis' is a colormap
  # Add color bar to show the mapping between colors and values
plt.show()
